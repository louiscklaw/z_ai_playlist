# %% [markdown]
# # Selector Group Chat

# %%
from typing import List, Sequence

from autogen_agentchat.agents import AssistantAgent, UserProxyAgent
from autogen_agentchat.conditions import MaxMessageTermination, TextMentionTermination
from autogen_agentchat.messages import BaseAgentEvent, BaseChatMessage
from autogen_agentchat.teams import SelectorGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
# Note: This example uses mock tools instead of real APIs for demonstration purposes
def search_web_tool(query: str) -> str:
    if "2006-2007" in query:
        return """Here are the total points scored by Miami Heat players in the 2006-2007 season:
        Udonis Haslem: 844 points
        Dwayne Wade: 1397 points
        James Posey: 550 points
        ...
        """
    elif "2007-2008" in query:
        return "The number of total rebounds for Dwayne Wade in the Miami Heat season 2007-2008 is 214."
    elif "2008-2009" in query:
        return "The number of total rebounds for Dwayne Wade in the Miami Heat season 2008-2009 is 398."
    return "No data found."


def percentage_change_tool(start: float, end: float) -> float:
    return ((end - start) / start) * 100

# %%
text_mention_termination = TextMentionTermination("TERMINATE")
max_messages_termination = MaxMessageTermination(max_messages=25)
termination = text_mention_termination | max_messages_termination

# %%
selector_prompt = """
Select an agent to perform task.

{roles}

Current conversation context:
{history}

Read the above conversation, then select an agent from {participants} to perform the next task.
When the task is complete, let the user approve or disapprove the task.
""".strip()

# %%
import os,sys
from dotenv import load_dotenv


def configure():
    load_dotenv()
    return os.getenv("OPENROUTER_API_KEY")

model_client = OpenAIChatCompletionClient(
    model="GLM-4.5-Flash",
    api_key=configure(),
    # base_url="...",
    base_url="https://api.z.ai/api/paas/v4/",
    temperature=0.8,
    # max_tokens=20000,
    model_info={
        "vision": False,
        "function_calling": True,
        "json_output": True,
        "family": "unknown",
        "structured_output": True,
    },
)

planning_agent = AssistantAgent(
    "PlanningAgent",
    description="An agent for planning tasks, this agent should be the first to engage when given a new task.",
    model_client=model_client,
    system_message="""
    You are a planning agent.
    Your job is to break down complex tasks into smaller, manageable subtasks.
    Your team members are:
        WebSearchAgent: Searches for information
        DataAnalystAgent: Performs calculations

    You only plan and delegate tasks - you do not execute them yourself.

    When assigning tasks, use this format:
    1. <agent> : <task>

    After all tasks are complete, summarize the findings and end with "TERMINATE".
    """,
)

web_search_agent = AssistantAgent(
    "WebSearchAgent",
    description="An agent for searching information on the web.",
    tools=[search_web_tool],
    model_client=model_client,
    system_message="""
    You are a web search agent.
    Your only tool is search_tool - use it to find information.
    You make only one search call at a time.
    Once you have the results, you never do calculations based on them.
    """,
)

data_analyst_agent = AssistantAgent(
    "DataAnalystAgent",
    description="An agent for performing calculations.",
    model_client=model_client,
    tools=[percentage_change_tool],
    system_message="""
    You are a data analyst.
    Given the tasks you have been assigned, you should analyze the data and provide results using the tools provided.
    If you have not seen the data, ask for it.
    """,
)

# %%
task = "Who was the Miami Heat player with the highest points in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?"

# %%
user_proxy_agent = UserProxyAgent("UserProxyAgent", description="A proxy for the user to approve or disapprove tasks.")


def selector_func_with_user_proxy(messages: Sequence[BaseAgentEvent | BaseChatMessage]) -> str | None:
    if messages[-1].source != planning_agent.name and messages[-1].source != user_proxy_agent.name:
        # Planning agent should be the first to engage when given a new task, or check progress.
        return planning_agent.name
    if messages[-1].source == planning_agent.name:
        if messages[-2].source == user_proxy_agent.name and "APPROVE" in messages[-1].content.upper():  # type: ignore
            # User has approved the plan, proceed to the next agent.
            return None
        # Use the user proxy agent to get the user's approval to proceed.
        return user_proxy_agent.name
    if messages[-1].source == user_proxy_agent.name:
        # If the user does not approve, return to the planning agent.
        if "APPROVE" not in messages[-1].content.upper():  # type: ignore
            return planning_agent.name
    return None

team = SelectorGroupChat(
    [planning_agent, web_search_agent, data_analyst_agent, user_proxy_agent],
    model_client=model_client,
    termination_condition=termination,
    selector_prompt=selector_prompt,
    selector_func=selector_func_with_user_proxy,
    allow_repeated_speaker=True,
)

# Reset the previous agents and run the chat again with the user proxy agent and selector function.
await team.reset()

await Console(team.run_stream(task=task))
# Out:
# ---------- TextMessage (user) ----------
# Who was the Miami Heat player with the highest points in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?
# ---------- ThoughtEvent (PlanningAgent) ----------
# I need to break down this complex task into smaller, manageable subtasks. The question has two parts:
#
# 1. Find who was the Miami Heat player with the highest points in the 2006-2007 season
# 2. Find the percentage change in that player's total rebounds between the 2007-2008 and 2008-2009 seasons
#
# To accomplish this, I'll need to:
#
# 1. First search for information about Miami Heat players' points in the 2006-2007 season
# 2. Identify which player had the highest points
# 3. Search for that player's rebound statistics for the 2007-2008 season
# 4. Search for that player's rebound statistics for the 2008-2009 season
# 5. Calculate the percentage change in rebounds between those two seasons
#
# Let me assign these tasks to the appropriate agents:
#
# For the search tasks, I'll use the WebSearchAgent:
# - Search for Miami Heat players' points in the 2006-2007 season
# - Search for the identified player's rebounds in 2007-2008
# - Search for the identified player's rebounds in 2008-2009
#
# For the calculation task, I'll use the DataAnalystAgent:
# - Calculate the percentage change in rebounds between the two seasons
#
# Let me write these tasks in the required format:
# ---------- TextMessage (PlanningAgent) ----------
#
# I'll help you find this information by breaking it down into manageable tasks. Here's my plan:
#
# 1. WebSearchAgent : Search for Miami Heat player points statistics for the 2006-2007 season to identify the highest scorer
# 2. WebSearchAgent : Search for rebound statistics of the identified player for the 2007-2008 season
# 3. WebSearchAgent : Search for rebound statistics of the same player for the 2008-2009 season
# 4. DataAnalystAgent : Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons
# ---------- TextMessage (UserProxyAgent) ----------
# APPROVE
# ---------- ThoughtEvent (WebSearchAgent) ----------
#
# The user is asking me to approve something, but they haven't actually provided any task or action for me to approve. It seems like they might be confused about our interaction. I should clarify what they're asking me to approve.
#
# Looking at our conversation, I haven't actually taken any action yet or provided any results. The user asked me to find information about a Miami Heat player, but I haven't searched for anything yet. There's nothing for me to approve.
# ---------- TextMessage (WebSearchAgent) ----------
#
# I don't see any action or result for me to approve. I haven't performed any searches yet regarding the Miami Heat player statistics you asked about.
#
# If you'd like me to proceed with searching for the information about the Miami Heat player with the highest points in the 2006-2007 season and their rebound statistics for the subsequent seasons, I'd be happy to help. Just let me know if you'd like me to start those searches.
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# The user is pointing out that there was no actual execution of tasks in my previous response. I need to properly delegate the tasks to the appropriate agents using the format specified in my instructions.
#
# I need to break down the original question into manageable subtasks:
#
# 1. First, find out who was the Miami Heat player with the highest points in the 2006-2007 season.
# 2. Then, find that player's total rebounds in the 2007-2008 season.
# 3. Find that same player's total rebounds in the 2008-2009 season.
# 4. Calculate the percentage change between those two rebound numbers.
#
# For the first three tasks, I need the WebSearchAgent to find the statistics. For the fourth task, I need the DataAnalystAgent to perform the calculation.
#
# Let me assign these tasks properly:
# ---------- TextMessage (PlanningAgent) ----------
# You're right, I apologize for the confusion. Let me properly assign the tasks to get the information you need:
#
# 1. WebSearchAgent : Find the Miami Heat player with the highest points in the 2006-2007 season
# 2. WebSearchAgent : Get the total rebounds for that player in the 2007-2008 season
# 3. WebSearchAgent : Get the total rebounds for that same player in the 2008-2009 season
# 4. DataAnalystAgent : Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons
# ---------- TextMessage (UserProxyAgent) ----------
# APPROVE
# ---------- ThoughtEvent (WebSearchAgent) ----------
#
# I'll help you find this information step by step. Let me start by identifying the Miami Heat player with the highest points in the 2006-2007 season.
#
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_-8454570037358376996', arguments='{"query": "Miami Heat highest points leader 2006-2007 season"}', name='search_web_tool')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content='Here are the total points scored by Miami Heat players in the 2006-2007 season:\n        Udonis Haslem: 844 points\n        Dwayne Wade: 1397 points\n        James Posey: 550 points\n        ...\n        ', name='search_web_tool', call_id='call_-8454570037358376996', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# Here are the total points scored by Miami Heat players in the 2006-2007 season:
#         Udonis Haslem: 844 points
#         Dwayne Wade: 1397 points
#         James Posey: 550 points
#         ...
#
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# The user has provided partial information about Miami Heat players' points in the 2006-2007 season. From what they've shared:
#
# - Udonis Haslem: 844 points
# - Dwayne Wade: 1397 points
# - James Posey: 550 points
#
# Based on this information, it appears that Dwayne Wade had the highest points in the 2006-2007 season with 1397 points.
#
# However, the user hasn't provided complete information - they've indicated there are more players with "...". But since Dwayne Wade already has more points than the other two players listed (and these are typically the main scorers), it's reasonable to conclude that Dwayne Wade was the highest scorer in the 2006-2007 season.
#
# Now I need to find out what Dwayne Wade's rebound statistics were for the 2007-2008 and 2008-2009 seasons to calculate the percentage change. I should delegate this to the WebSearchAgent.
# ---------- TextMessage (PlanningAgent) ----------
#
# Based on the information provided, Dwayne Wade had the highest points in the 2006-2007 season with 1397 points.
#
# Now I need to find Dwyane Wade's rebound statistics for the 2007-2008 and 2008-2009 seasons to calculate the percentage change.
#
# 1. WebSearchAgent : Find Dwyane Wade's total rebounds in the 2007-2008 season
# 2. WebSearchAgent : Find Dwyane Wade's total rebounds in the 2008-2009 season
# 3. DataAnalystAgent : Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons
# ---------- TextMessage (UserProxyAgent) ----------
# APPROVE
# ---------- ThoughtEvent (WebSearchAgent) ----------
#
#
# I approve your plan. Let's start by finding Dwyane Wade's total rebounds in the 2007-2008 season.
#
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_-8454583300218320674', arguments='{"query": "Dwyane Wade total rebounds 2007-2008 season Miami Heat"}', name='search_web_tool')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content='The number of total rebounds for Dwayne Wade in the Miami Heat season 2007-2008 is 214.', name='search_web_tool', call_id='call_-8454583300218320674', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# The number of total rebounds for Dwayne Wade in the Miami Heat season 2007-2008 is 214.
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# I now have:
# - The Miami Heat player with the highest points in the 2006-2007 season: Dwayne Wade (1397 points)
# - Dwayne Wade's total rebounds in the 2007-2008 season: 214
#
# I still need Dwayne Wade's rebounds in the 2008-2009 season to calculate the percentage change. Let me assign the task to get that information.
# ---------- TextMessage (PlanningAgent) ----------
#
# 1. WebSearchAgent : Find Dwayne Wade's total rebounds for the Miami Heat in the 2008-2009 season
# ---------- TextMessage (UserProxyAgent) ----------
# APPROVE
# ---------- ThoughtEvent (WebSearchAgent) ----------
#
#
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_-8454593505061999324', arguments='{"query": "Dwayne Wade total rebounds 2008-2009 season Miami Heat"}', name='search_web_tool')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content='The number of total rebounds for Dwayne Wade in the Miami Heat season 2008-2009 is 398.', name='search_web_tool', call_id='call_-8454593505061999324', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# The number of total rebounds for Dwayne Wade in the Miami Heat season 2008-2009 is 398.
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# The user has now provided me with the total rebounds for Dwayne Wade in the 2008-2009 season, which is 398.
#
# Previously, I was given:
# - Dwayne Wade's rebounds in 2007-2008: 214
# - Dwyane Wade's rebounds in 2008-2009: 398
#
# Now I can calculate the percentage change in his total rebounds between these two seasons.
#
# The formula for percentage change is:
# ((New Value - Old Value) / Old Value) * 100
#
# So the percentage change would be:
# ((398 - 214) / 214) * 100
# = (184 / 214) * 100
# = 0.8598 * 100
# = 85.98%
#
# So the percentage change in Dwyane Wade's total rebounds between the 2007-2008 and 2008-2009 seasons was approximately 85.98%.
#
# I should delegate this calculation to the DataAnalystAgent.
# ---------- TextMessage (PlanningAgent) ----------
#
# 1. DataAnalystAgent : Calculate the percentage change in Dwyane Wade's total rebounds between the 2007-2008 season (214 rebounds) and the 2008-2009 season (398 rebounds)
# ---------- TextMessage (UserProxyAgent) ----------
# APPROVE
# ---------- ThoughtEvent (DataAnalystAgent) ----------
#
#
# ---------- ToolCallRequestEvent (DataAnalystAgent) ----------
# [FunctionCall(id='call_-8454582441224803564', arguments='{"start": 214, "end": 398}', name='percentage_change_tool')]
# ---------- ToolCallExecutionEvent (DataAnalystAgent) ----------
# [FunctionExecutionResult(content='85.98130841121495', name='percentage_change_tool', call_id='call_-8454582441224803564', is_error=False)]
# ---------- ToolCallSummaryMessage (DataAnalystAgent) ----------
# 85.98130841121495
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# The DataAnalystAgent has provided a calculation result of 85.98130841121495, which should be the percentage change in Dwayne Wade's rebounds between the 2007-2008 and 2008-2009 seasons.
#
# To verify this calculation:
# - 2007-2008 rebounds: 214
# - 2008-2009 rebounds: 398
#
# Percentage change formula: ((New Value - Old Value) / Old Value) * 100
# ((398 - 214) / 214) * 100 = (184 / 214) * 100 = 0.8598130841121495 * 100 = 85.98130841121495%
#
# The calculation is correct. Dwyane Wade's rebounds increased by approximately 85.98% from the 2007-2008 season to the 2008-2009 season.
#
# Now I can summarize the findings:
# 1. Dwayne Wade had the highest points for the Miami Heat in the 2006-2007 season with 1397 points.
# 2. His total rebounds increased from 214 in 2007-2008 to 398 in 2008-2009.
# 3. This represents a percentage increase of approximately 85.98%.
#
# I'll now provide the final answer and end with "TERMINATE".
# ---------- TextMessage (PlanningAgent) ----------
# Based on the information gathered:
#
# 1. Dwayne Wade was the Miami Heat player with the highest points in the 2006-2007 season, scoring 1397 points.
#
# 2. For the rebounds calculation:
#    - 2007-2008 season: 214 rebounds
#    - 2008-2009 season: 398 rebounds
#    - Percentage change: 85.98%
#
# The percentage change in Dwayne Wade's total rebounds between the 2007-2008 and 2008-2009 seasons was an increase of approximately 85.98%.
#
# TERMINATE
# TaskResult(messages=[TextMessage(id='089ee20e-dcb2-4f9f-87c7-6d5dad381605', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 29, 55, 790977, tzinfo=datetime.timezone.utc), content='Who was the Miami Heat player with the highest points in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?', type='TextMessage'), ThoughtEvent(id='5f1fc02c-7a57-42a8-8096-20beefd97c0f', source='PlanningAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 30, 1, 840633, tzinfo=datetime.timezone.utc), content="I need to break down this complex task into smaller, manageable subtasks. The question has two parts:\n\n1. Find who was the Miami Heat player with the highest points in the 2006-2007 season\n2. Find the percentage change in that player's total rebounds between the 2007-2008 and 2008-2009 seasons\n\nTo accomplish this, I'll need to:\n\n1. First search for information about Miami Heat players' points in the 2006-2007 season\n2. Identify which player had the highest points\n3. Search for that player's rebound statistics for the 2007-2008 season\n4. Search for that player's rebound statistics for the 2008-2009 season\n5. Calculate the percentage change in rebounds between those two seasons\n\nLet me assign these tasks to the appropriate agents:\n\nFor the search tasks, I'll use the WebSearchAgent:\n- Search for Miami Heat players' points in the 2006-2007 season\n- Search for the identified player's rebounds in 2007-2008\n- Search for the identified player's rebounds in 2008-2009\n\nFor the calculation task, I'll use the DataAnalystAgent:\n- Calculate the percentage change in rebounds between the two seasons\n\nLet me write these tasks in the required format:", type='ThoughtEvent'), TextMessage(id='bdb57c37-ccaa-4183-be0d-fe5d1b21e972', source='PlanningAgent', models_usage=RequestUsage(prompt_tokens=154, completion_tokens=403), metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 30, 1, 840876, tzinfo=datetime.timezone.utc), content="\nI'll help you find this information by breaking it down into manageable tasks. Here's my plan:\n\n1. WebSearchAgent : Search for Miami Heat player points statistics for the 2006-2007 season to identify the highest scorer\n2. WebSearchAgent : Search for rebound statistics of the identified player for the 2007-2008 season\n3. WebSearchAgent : Search for rebound statistics of the same player for the 2008-2009 season\n4. DataAnalystAgent : Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons", type='TextMessage'), UserInputRequestedEvent(id='57b9f73f-766d-4d33-98c8-11d02f3d6b72', source='UserProxyAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 30, 1, 842587, tzinfo=datetime.timezone.utc), request_id='e9da4b2d-9079-4b13-8d14-8e6fec754bf8', content='', type='UserInputRequestedEvent'), TextMessage(id='c9ae7cbb-4852-499d-8763-41dcc73e6929', source='UserProxyAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 30, 4, 976384, tzinfo=datetime.timezone.utc), content='APPROVE', type='TextMessage'), ThoughtEvent(id='5e85963d-1508-403e-a407-991fe4fe1fc6', source='WebSearchAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 30, 20, 422869, tzinfo=datetime.timezone.utc), content="\nThe user is asking me to approve something, but they haven't actually provided any task or action for me to approve. It seems like they might be confused about our interaction. I should clarify what they're asking me to approve.\n\nLooking at our conversation, I haven't actually taken any action yet or provided any results. The user asked me to find information about a Miami Heat player, but I haven't searched for anything yet. There's nothing for me to approve.", type='ThoughtEvent'), TextMessage(id='f2184e46-a794-4876-bbcb-a5bcb4544d0c', source='WebSearchAgent', models_usage= ...

# %% [markdown]
# Now we run the team with a task to find information about an NBA player.

# %% [markdown]
# As we can see, after the Web Search Agent conducts the necessary searches and the Data Analyst Agent completes the necessary calculations, we find that Dwayne Wade was the Miami Heat player with the highest points in the 2006-2007 season, and the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons is 85.98%!

# %% [markdown]
# ## Custom Selector Function

# %% [markdown]
# Often times we want better control over the selection process.
# To this end, we can set the `selector_func` argument with a custom selector function to override the default model-based selection.
# This allows us to implement more complex selection logic and state-based transitions.
#
# For instance, we want the Planning Agent to speak immediately after any specialized agent to check the progress.
#
# ```{note}
# Returning `None` from the custom selector function will use the default model-based selection.
# ```
#
# ```{note}
# Custom selector functions are not [serialized](https://microsoft.github.io/autogen/stable/user-guide/agentchat-user-guide/serialize-components.html) when `.dump_component()` is called on the SelectorGroupChat team . If you need to serialize team configurations with custom selector functions, consider implementing custom workflows and serialization logic.
# ```

# %%
def selector_func(messages: Sequence[BaseAgentEvent | BaseChatMessage]) -> str | None:
    if messages[-1].source != planning_agent.name:
        return planning_agent.name
    return None


# Reset the previous team and run the chat again with the selector function.
await team.reset()
team = SelectorGroupChat(
    [planning_agent, web_search_agent, data_analyst_agent],
    model_client=model_client,
    termination_condition=termination,
    selector_prompt=selector_prompt,
    allow_repeated_speaker=True,
    selector_func=selector_func,
)

await Console(team.run_stream(task=task))
# Out:
# ---------- TextMessage (user) ----------
# Who was the Miami Heat player with the highest points in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# This question requires me to find specific basketball statistics about the Miami Heat player. Let me break this down into smaller subtasks:
#
# 1. First, I need to identify who was the Miami Heat player with the highest points in the 2006-2007 season.
# 2. Then, I need to find that player's total rebounds in the 2007-2008 season.
# 3. Next, I need to find that player's total rebounds in the 2008-2009 season.
# 4. Finally, I need to calculate the percentage change in rebounds between those two seasons.
#
# Let me assign these tasks to the appropriate agents:
#
# For the first three tasks, I need to find specific basketball statistics, which would be best handled by the WebSearchAgent who can search for this information.
#
# The final task involves calculating a percentage change, which would be best handled by the DataAnalystAgent.
#
# So my task delegation would be:
#
# 1. WebSearchAgent: Find the Miami Heat player with the highest points in the 2006-2007 season
# 2. WebSearchAgent: Find that player's total rebounds in the 2007-2008 season
# 3. WebSearchAgent: Find that player's total rebounds in the 2008-2009 season
# 4. DataAnalystAgent: Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons
#
# After these tasks are completed, I'll summarize the findings as requested.
# ---------- TextMessage (PlanningAgent) ----------
# I'll help you find this information by breaking it down into manageable tasks.
#
# 1. WebSearchAgent: Find the Miami Heat player with the highest points in the 2006-2007 season
# 2. WebSearchAgent: Find that player's total rebounds in the 2007-2008 season
# 3. WebSearchAgent: Find that player's total rebounds in the 2008-2009 season
# 4. DataAnalystAgent: Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons
# ---------- ThoughtEvent (WebSearchAgent) ----------
#
#
# I'll help you find this information step by step. Let me start by searching for the Miami Heat player with the highest points in the 2006-2007 season.
#
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_-8454584880766432599', arguments='{"query": "Miami Heat leading scorer 2006-2007 season"}', name='search_web_tool')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content='Here are the total points scored by Miami Heat players in the 2006-2007 season:\n        Udonis Haslem: 844 points\n        Dwayne Wade: 1397 points\n        James Posey: 550 points\n        ...\n        ', name='search_web_tool', call_id='call_-8454584880766432599', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# Here are the total points scored by Miami Heat players in the 2006-2007 season:
#         Udonis Haslem: 844 points
#         Dwayne Wade: 1397 points
#         James Posey: 550 points
#         ...
#
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# I have the information about the Miami Heat players' points in the 2006-2007 season. From this data, I can see that Dwayne Wade scored the highest points with 1397 points.
#
# Now I need to find:
# 1. Dwayne Wade's total rebounds in the 2007-2008 season
# 2. Dwayne Wade's total rebounds in the 2008-2009 season
# 3. Calculate the percentage change in rebounds between these two seasons
#
# Since I don't have this information yet, I need to delegate the search to the WebSearchAgent.
#
# My plan:
# 1. WebSearchAgent: Find Dwayne Wade's total rebounds in the 2007-2008 season
# 2. WebSearchAgent: Find Dwayne Wade's total rebounds in the 2008-2009 season
# 3. DataAnalystAgent: Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons
# ---------- TextMessage (PlanningAgent) ----------
# Based on the information provided, Dwayne Wade had the highest points in the 2006-2007 season with 1397 points.
#
# Now I need to find his rebound statistics for the following two seasons to calculate the percentage change:
#
# 1. WebSearchAgent: Find Dwayne Wade's total rebounds in the 2007-2008 season
# 2. WebSearchAgent: Find Dwayne Wade's total rebounds in the 2008-2009 season
# 3. DataAnalystAgent: Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons
# ---------- ThoughtEvent (WebSearchAgent) ----------
#
#
#
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_-8454592817867060648', arguments='{"query": "Dwayne Wade rebounds 2007-2008 season"}', name='search_web_tool')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content='The number of total rebounds for Dwayne Wade in the Miami Heat season 2007-2008 is 214.', name='search_web_tool', call_id='call_-8454592817867060648', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# The number of total rebounds for Dwayne Wade in the Miami Heat season 2007-2008 is 214.
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# The user has provided information about Dwayne Wade's rebounds for the 2007-2008 season (214 rebounds). I still need to find his rebounds for the 2008-2009 season to calculate the percentage change.
#
# Based on the information provided so far:
# 1. Dwayne Wade had the highest points in the 2006-2007 season with 1397 points.
# 2. He had 214 rebounds in the 2007-2008 season.
#
# Now I need to find his rebounds for the 2008-2009 season to complete the percentage change calculation.
# ---------- TextMessage (PlanningAgent) ----------
#
# I now have Dwayne Wade's rebounds for the 2007-2008 season (214 rebounds). To calculate the percentage change, I still need his rebounds for the 2008-2009 season.
#
# 1. WebSearchAgent: Find Dwayne Wade's total rebounds in the Miami Heat 2008-2009 season
# 2. DataAnalystAgent: Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons
# ---------- ThoughtEvent (WebSearchAgent) ----------
#
#
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_-8454570930711680847', arguments='{"query": "Dwayne Wade rebounds 2008-2009 season Miami Heat"}', name='search_web_tool')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content='The number of total rebounds for Dwayne Wade in the Miami Heat season 2008-2009 is 398.', name='search_web_tool', call_id='call_-8454570930711680847', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# The number of total rebounds for Dwayne Wade in the Miami Heat season 2008-2009 is 398.
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# I now have all the information needed to answer the question:
#
# 1. Who was the Miami Heat player with the highest points in the 2006-2007 season?
#    - Based on the data provided: Dwayne Wade with 1397 points
#
# 2. What was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?
#    - 2007-2008 season: 214 rebounds
#    - 2008-2009 season: 398 rebounds
#
#    To calculate percentage change:
#    ((New Value - Old Value) / Old Value) * 100
#    ((398 - 214) / 214) * 100
#    (184 / 214) * 100
#    0.8598 * 100
#    85.98%
#
# So the percentage change in rebounds is approximately 85.98%.
#
# Now I need to delegate this calculation to the DataAnalystAgent.
# ---------- TextMessage (PlanningAgent) ----------
#
# 1. DataAnalystAgent: Calculate the percentage change in Dwayne Wade's rebounds between the 2007-2008 season (214 rebounds) and the 2008-2009 season (398 rebounds)
# ---------- ThoughtEvent (DataAnalystAgent) ----------
#
# Now I can calculate the percentage change in Dwayne Wade's rebounds between the 2007-2008 and 2008-2009 seasons.
#
# ---------- ToolCallRequestEvent (DataAnalystAgent) ----------
# [FunctionCall(id='call_-8454593505061991387', arguments='{"start": 214, "end": 398}', name='percentage_change_tool')]
# ---------- ToolCallExecutionEvent (DataAnalystAgent) ----------
# [FunctionExecutionResult(content='85.98130841121495', name='percentage_change_tool', call_id='call_-8454593505061991387', is_error=False)]
# ---------- ToolCallSummaryMessage (DataAnalystAgent) ----------
# 85.98130841121495
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# Let me analyze what information I have and what I need to do:
#
# 1. I've identified that Dwayne Wade was the Miami Heat player with the highest points in the 2006-2007 season (1397 points).
#
# 2. I've been given:
#    - Dwayne Wade's total rebounds in 2007-2008: 214 rebounds
#    - Dwayne Wade's total rebounds in 2008-2009: 398 rebounds
#    - A number: 85.98130841121495
#
# 3. This last number appears to be the percentage change calculation that the DataAnalystAgent computed. Let me verify this calculation:
#
# To calculate the percentage change from 2007-2008 to 2008-2009:
# - Formula: ((New Value - Old Value) / Old Value) × 100
# - ((398 - 214) / 214) × 100 = (184 / 214) × 100 = 0.8598130841121495 × 100 = 85.98130841121495%
#
# So the percentage change in Dwayne Wade's total rebounds between the 2007-2008 and 2008-2009 seasons is approximately 85.98%.
#
# Now I can summarize the findings:
#
# 1. Dwayne Wade was the Miami Heat player with the highest points in the 2006-2007 season (1397 points).
# 2. His total rebounds increased from 214 in the 2007-2008 season to 398 in the 2008-2009 season.
# 3. This represents a percentage increase of approximately 85.98%.
#
# I'll now provide a complete summary and end with "TERMINATE".
# ---------- TextMessage (PlanningAgent) ----------
# Based on the information gathered:
#
# 1. Dwayne Wade was the Miami Heat player with the highest points in the 2006-2007 season with 1397 points.
#
# 2. His total rebounds changed as follows:
#    - 2007-2008 season: 214 rebounds
#    - 2008-2009 season: 398 rebounds
#
# 3. The percentage change in his total rebounds between these two seasons was approximately 85.98% (an increase).
#
# TERMINATE
# TaskResult(messages=[TextMessage(id='b3157bb5-fb54-4d61-85cc-fa325cbe6406', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 32, 40, 668789, tzinfo=datetime.timezone.utc), content='Who was the Miami Heat player with the highest points in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?', type='TextMessage'), ThoughtEvent(id='5719a231-2d0e-401d-8b6d-91d0768dd9d7', source='PlanningAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 32, 48, 659359, tzinfo=datetime.timezone.utc), content="\nThis question requires me to find specific basketball statistics about the Miami Heat player. Let me break this down into smaller subtasks:\n\n1. First, I need to identify who was the Miami Heat player with the highest points in the 2006-2007 season.\n2. Then, I need to find that player's total rebounds in the 2007-2008 season.\n3. Next, I need to find that player's total rebounds in the 2008-2009 season.\n4. Finally, I need to calculate the percentage change in rebounds between those two seasons.\n\nLet me assign these tasks to the appropriate agents:\n\nFor the first three tasks, I need to find specific basketball statistics, which would be best handled by the WebSearchAgent who can search for this information.\n\nThe final task involves calculating a percentage change, which would be best handled by the DataAnalystAgent.\n\nSo my task delegation would be:\n\n1. WebSearchAgent: Find the Miami Heat player with the highest points in the 2006-2007 season\n2. WebSearchAgent: Find that player's total rebounds in the 2007-2008 season\n3. WebSearchAgent: Find that player's total rebounds in the 2008-2009 season\n4. DataAnalystAgent: Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons\n\nAfter these tasks are completed, I'll summarize the findings as requested.", type='ThoughtEvent'), TextMessage(id='6f4528f4-bf1e-4a99-8d9b-54795b82580b', source='PlanningAgent', models_usage=RequestUsage(prompt_tokens=154, completion_tokens=416), metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 32, 48, 659576, tzinfo=datetime.timezone.utc), content="I'll help you find this information by breaking it down into manageable tasks.\n\n1. WebSearchAgent: Find the Miami Heat player with the highest points in the 2006-2007 season\n2. WebSearchAgent: Find that player's total rebounds in the 2007-2008 season\n3. WebSearchAgent: Find that player's total rebounds in the 2008-2009 season\n4. DataAnalystAgent: Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons", type='TextMessage'), ThoughtEvent(id='9b724522-e04a-4eb1-8308-ec357b6d696e', source='WebSearchAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 33, 4, 291832, tzinfo=datetime.timezone.utc), content="\n\nI'll help you find this information step by step. Let me start by searching for the Miami Heat player with the highest points in the 2006-2007 season.\n", type='ThoughtEvent'), ToolCallRequestEvent(id='c9588119-cd41-4d7f-9412-b483f920add9', source='WebSearchAgent', models_usage=RequestUsage(prompt_tokens=375, completion_tokens=141), metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 33, 4, 292097, tzinfo=datetime.timezone.utc), content=[FunctionCall(id='call_-8454584880766432599', arguments='{"query": "Miami Heat leading scorer 2006-2007 season"}', name='search_web_tool')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(id='fb209e70-bf90-4f99-9e5f-3e19ca507a18', source='WebSearchAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 33, 4, 294207, tzinfo=datetime.timezone.utc), content=[FunctionExecutionResult(content='Here are the total points scored by Miami Heat players in the 2006-2007 season:\n        Udonis Haslem: 844 points\n        Dwayne Wade: 1397 points\n        James Posey: 550 points\n        ...\n        ', na ...

# %% [markdown]
# You can see from the conversation log that the Planning Agent always speaks immediately after the specialized agents.
#
# ```{tip}
# Each participant agent only makes one step (executing tools, generating a response, etc.)
# on each turn.
# If you want an {py:class}`~autogen_agentchat.agents.AssistantAgent` to repeat
# until it stop returning a {py:class}`~autogen_agentchat.messages.ToolCallSummaryMessage`
# when it has finished running all the tools it needs to run, you can do so by
# checking the last message and returning the agent if it is a
# {py:class}`~autogen_agentchat.messages.ToolCallSummaryMessage`.
# ```

# %% [markdown]
# ## Custom Candidate Function

# %% [markdown]
# One more possible requirement might be to automatically select the next speaker from a filtered list of agents.
# For this, we can set `candidate_func` parameter with a custom candidate function to filter down the list of potential agents for speaker selection for each turn of groupchat.
#
# This allow us to restrict speaker selection to a specific set of agents after a given agent.
#
#
# ```{note}
# The `candidate_func` is only valid if `selector_func` is not set.
# Returning `None` or an empty list `[]` from the custom candidate function will raise a `ValueError`.
# ```

# %%
def candidate_func(messages: Sequence[BaseAgentEvent | BaseChatMessage]) -> List[str]:
    # keep planning_agent first one to plan out the tasks
    if messages[-1].source == "user":
        return [planning_agent.name]

    # if previous agent is planning_agent and if it explicitely asks for web_search_agent
    # or data_analyst_agent or both (in-case of re-planning or re-assignment of tasks)
    # then return those specific agents
    last_message = messages[-1]
    if last_message.source == planning_agent.name:
        participants = []
        if web_search_agent.name in last_message.to_text():
            participants.append(web_search_agent.name)
        if data_analyst_agent.name in last_message.to_text():
            participants.append(data_analyst_agent.name)
        if participants:
            return participants  # SelectorGroupChat will select from the remaining two agents.

    # we can assume that the task is finished once the web_search_agent
    # and data_analyst_agent have took their turns, thus we send
    # in planning_agent to terminate the chat
    previous_set_of_agents = set(message.source for message in messages)
    if web_search_agent.name in previous_set_of_agents and data_analyst_agent.name in previous_set_of_agents:
        return [planning_agent.name]

    # if no-conditions are met then return all the agents
    return [planning_agent.name, web_search_agent.name, data_analyst_agent.name]


# Reset the previous team and run the chat again with the selector function.
await team.reset()
team = SelectorGroupChat(
    [planning_agent, web_search_agent, data_analyst_agent],
    model_client=model_client,
    termination_condition=termination,
    candidate_func=candidate_func,
)

await Console(team.run_stream(task=task))
# Out:
# ---------- TextMessage (user) ----------
# Who was the Miami Heat player with the highest points in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# To answer this question, I need to find:
#
# 1. Who was the Miami Heat player with the highest points in the 2006-2007 season
# 2. What was that player's total rebounds in the 2007-2008 season
# 3. What was that player's total rebounds in the 2008-2009 season
# 4. Calculate the percentage change in rebounds between those two seasons
#
# Let me break this down into tasks:
#
# 1. WebSearchAgent: Find the Miami Heat player with the highest points in the 2006-2007 season
# 2. WebSearchAgent: Find that player's total rebounds in the 2007-2008 season
# 3. WebSearchAgent: Find that player's total rebounds in the 2008-2009 season
# 4. DataAnalystAgent: Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons
#
# Once I have all this information, I can provide a complete answer.
# ---------- TextMessage (PlanningAgent) ----------
# 1. WebSearchAgent : Find the Miami Heat player with the highest points in the 2006-2007 NBA season
# 2. WebSearchAgent : Find that player's total rebounds in the 2007-2008 NBA season
# 3. WebSearchAgent : Find that player's total rebounds in the 2008-2009 NBA season
# 4. DataAnalystAgent : Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons
# ---------- ThoughtEvent (WebSearchAgent) ----------
#
# I'll help you find that information step by step. Let me start by identifying the Miami Heat player with the highest points in the 2006-2007 season.
#
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_-8454591477836969408', arguments='{"query": "Miami Heat player highest points 2006-2007 NBA season"}', name='search_web_tool')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content='Here are the total points scored by Miami Heat players in the 2006-2007 season:\n        Udonis Haslem: 844 points\n        Dwayne Wade: 1397 points\n        James Posey: 550 points\n        ...\n        ', name='search_web_tool', call_id='call_-8454591477836969408', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# Here are the total points scored by Miami Heat players in the 2006-2007 season:
#         Udonis Haslem: 844 points
#         Dwayne Wade: 1397 points
#         James Posey: 550 points
#         ...
#
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# I'm given partial data about Miami Heat players and their points in the 2006-2007 season. From what's provided:
#
# - Udonis Haslem: 844 points
# - Dwayne Wade: 1397 points
# - James Posey: 550 points
#
# From this data, I can see that Dwayne Wade had the highest points with 1397 points.
#
# Now I need to find:
# 1. Dwayne Wade's total rebounds in the 2007-2008 season
# 2. Dwayne Wade's total rebounds in the 2008-2009 season
# 3. Calculate the percentage change in rebounds between these two seasons
#
# I should delegate these tasks to the appropriate agents.
# ---------- TextMessage (PlanningAgent) ----------
#
# 1. WebSearchAgent : Find Dwayne Wade's total rebounds in the 2007-2008 NBA season
# 2. WebSearchAgent : Find Dwayne Wade's total rebounds in the 2008-2009 NBA season
# 3. DataAnalystAgent : Calculate the percentage change in Dwayne Wade's rebounds between the 2007-2008 and 2008-2009 seasons
# ---------- ThoughtEvent (WebSearchAgent) ----------
#
#
#
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_-8454584056132646149', arguments='{"query": "Dwayne Wade total rebounds 2007-2008 NBA season"}', name='search_web_tool')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content='The number of total rebounds for Dwayne Wade in the Miami Heat season 2007-2008 is 214.', name='search_web_tool', call_id='call_-8454584056132646149', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# The number of total rebounds for Dwayne Wade in the Miami Heat season 2007-2008 is 214.
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# The user has provided the total rebounds for Dwayne Wade in the 2007-2008 season (214 rebounds). Now I need to find his total rebounds in the 2008-2009 season to calculate the percentage change.
#
# From the previous information, I know:
# 1. Dwayne Wade was the Miami Heat player with the highest points in the 2006-2007 season (1397 points)
# 2. His total rebounds in the 2007-2008 season was 214 rebounds
#
# Now I need to find his rebounds in the 2008-2009 season to complete the percentage change calculation.
# ---------- TextMessage (PlanningAgent) ----------
#
# 1. WebSearchAgent : Find Dwayne Wade's total rebounds in the 2008-2009 NBA season
# ---------- ThoughtEvent (WebSearchAgent) ----------
#
#
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_-8454590172166607619', arguments='{"query": "Dwayne Wade total rebounds 2008-2009 NBA season"}', name='search_web_tool')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content='The number of total rebounds for Dwayne Wade in the Miami Heat season 2008-2009 is 398.', name='search_web_tool', call_id='call_-8454590172166607619', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# The number of total rebounds for Dwayne Wade in the Miami Heat season 2008-2009 is 398.
# ---------- ThoughtEvent (DataAnalystAgent) ----------
#
# Now I can calculate the percentage change in Dwayne Wade's rebounds between the 2007-2008 and 2008-2009 seasons.
#
# ---------- ToolCallRequestEvent (DataAnalystAgent) ----------
# [FunctionCall(id='call_-8454590962440827606', arguments='{"start": 214, "end": 398}', name='percentage_change_tool')]
# ---------- ToolCallExecutionEvent (DataAnalystAgent) ----------
# [FunctionExecutionResult(content='85.98130841121495', name='percentage_change_tool', call_id='call_-8454590962440827606', is_error=False)]
# ---------- ToolCallSummaryMessage (DataAnalystAgent) ----------
# 85.98130841121495
# ---------- ThoughtEvent (PlanningAgent) ----------
#
# Let me analyze what we have so far:
#
# 1. From the first message, I determined that Dwayne Wade was the Miami Heat player with the highest points in the 2006-2007 season with 1397 points.
#
# 2. Then I was given that Dwayne Wade had 214 total rebounds in the 2007-2008 season.
#
# 3. Next, I was given that Dwayne Wade had 398 total rebounds in the 2008-2009 season.
#
# 4. Now I've been given a number: 85.98130841121495
#
# This appears to be the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons. Let me verify this calculation:
#
# Percentage change formula: ((New Value - Old Value) / Old Value) * 100
#
# For Dwayne Wade's rebounds:
# - Old Value (2007-2008): 214
# - New Value (2008-2009): 398
#
# Calculation:
# ((398 - 214) / 214) * 100 = (184 / 214) * 100 = 0.8598130841121495 * 100 = 85.98130841121495%
#
# This matches the number provided. So it seems the calculation has already been performed and I just need to summarize the findings.
#
# Summary:
# - Dwayne Wade was the Miami Heat player with the highest points in the 2006-2007 season (1397 points)
# - His rebounds increased from 214 in 2007-2008 to 398 in 2008-2009
# - The percentage change in rebounds was 85.98% (an increase)
#
# Now I'll provide the final summary and terminate.
# ---------- TextMessage (PlanningAgent) ----------
# Based on the information provided:
#
# 1. Dwayne Wade was the Miami Heat player with the highest points in the 2006-2007 season with 1397 points.
#
# 2. Dwayne Wade's rebounds changed from 214 in the 2007-2008 season to 398 in the 2008-2009 season.
#
# 3. The percentage change in his rebounds between these seasons was 85.98% (an increase).
#
# TERMINATE
# TaskResult(messages=[TextMessage(id='ca5d037e-a34b-4738-acc7-8ff46c55d963', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 35, 0, 209938, tzinfo=datetime.timezone.utc), content='Who was the Miami Heat player with the highest points in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?', type='TextMessage'), ThoughtEvent(id='5c5c6aad-2351-4275-bd30-50a6866feb38', source='PlanningAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 35, 5, 230251, tzinfo=datetime.timezone.utc), content="\nTo answer this question, I need to find:\n\n1. Who was the Miami Heat player with the highest points in the 2006-2007 season\n2. What was that player's total rebounds in the 2007-2008 season\n3. What was that player's total rebounds in the 2008-2009 season\n4. Calculate the percentage change in rebounds between those two seasons\n\nLet me break this down into tasks:\n\n1. WebSearchAgent: Find the Miami Heat player with the highest points in the 2006-2007 season\n2. WebSearchAgent: Find that player's total rebounds in the 2007-2008 season\n3. WebSearchAgent: Find that player's total rebounds in the 2008-2009 season\n4. DataAnalystAgent: Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons\n\nOnce I have all this information, I can provide a complete answer.", type='ThoughtEvent'), TextMessage(id='627bf960-afd5-41a3-a3d6-181b21941e6f', source='PlanningAgent', models_usage=RequestUsage(prompt_tokens=154, completion_tokens=309), metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 35, 5, 230421, tzinfo=datetime.timezone.utc), content="1. WebSearchAgent : Find the Miami Heat player with the highest points in the 2006-2007 NBA season\n2. WebSearchAgent : Find that player's total rebounds in the 2007-2008 NBA season\n3. WebSearchAgent : Find that player's total rebounds in the 2008-2009 NBA season\n4. DataAnalystAgent : Calculate the percentage change in rebounds between the 2007-2008 and 2008-2009 seasons", type='TextMessage'), ThoughtEvent(id='5f3512eb-e481-4993-ad5f-9272a04bed33', source='WebSearchAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 35, 10, 64448, tzinfo=datetime.timezone.utc), content="\nI'll help you find that information step by step. Let me start by identifying the Miami Heat player with the highest points in the 2006-2007 season.\n", type='ThoughtEvent'), ToolCallRequestEvent(id='39058ce8-0a7e-486b-bdd8-5d6d0b23de9a', source='WebSearchAgent', models_usage=RequestUsage(prompt_tokens=363, completion_tokens=178), metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 35, 10, 64667, tzinfo=datetime.timezone.utc), content=[FunctionCall(id='call_-8454591477836969408', arguments='{"query": "Miami Heat player highest points 2006-2007 NBA season"}', name='search_web_tool')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(id='101d8bf9-5fdc-4280-856d-84be5fda3911', source='WebSearchAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 35, 10, 66830, tzinfo=datetime.timezone.utc), content=[FunctionExecutionResult(content='Here are the total points scored by Miami Heat players in the 2006-2007 season:\n        Udonis Haslem: 844 points\n        Dwayne Wade: 1397 points\n        James Posey: 550 points\n        ...\n        ', name='search_web_tool', call_id='call_-8454591477836969408', is_error=False)], type='ToolCallExecutionEvent'), ToolCallSummaryMessage(id='32ba21ff-b16c-4fba-8231-5af0614179de', source='WebSearchAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 7, 35, 10, 67005, tzinfo=datetime.timezone.utc), content='Here are the total points scored by Miami Heat players in the 2006-2007 season:\n        Udonis Haslem: 844 points\n        Dwayne Wade: 1397 points\n        James Posey: 550 points\n        ...\n        ', type='ToolCallSummaryMessage', too ...

# %% [markdown]
# You can see from the conversation log that the Planning Agent returns to conversation once the Web Search Agent and Data Analyst Agent took their turns and it finds that the task was not finished as expected so it called the WebSearchAgent again to get rebound values and then called DataAnalysetAgent to get the percentage change.

# %% [markdown]
# ## User Feedback
#
# We can add {py:class}`~autogen_agentchat.agents.UserProxyAgent` to the team to
# provide user feedback during a run.
# See [Human-in-the-Loop](./tutorial/human-in-the-loop.ipynb) for more details
# about {py:class}`~autogen_agentchat.agents.UserProxyAgent`.
#
# To use the {py:class}`~autogen_agentchat.agents.UserProxyAgent` in the
# web search example, we simply add it to the team and update the selector function
# to always check for user feedback after the planning agent speaks.
# If the user responds with `"APPROVE"`, the conversation continues, otherwise,
# the planning agent tries again, until the user approves.

# %%
user_proxy_agent = UserProxyAgent("UserProxyAgent", description="A proxy for the user to approve or disapprove tasks.")


def selector_func_with_user_proxy(messages: Sequence[BaseAgentEvent | BaseChatMessage]) -> str | None:
    if messages[-1].source != planning_agent.name and messages[-1].source != user_proxy_agent.name:
        # Planning agent should be the first to engage when given a new task, or check progress.
        return planning_agent.name
    if messages[-1].source == planning_agent.name:
        if messages[-2].source == user_proxy_agent.name and "APPROVE" in messages[-1].content.upper():  # type: ignore
            # User has approved the plan, proceed to the next agent.
            return None
        # Use the user proxy agent to get the user's approval to proceed.
        return user_proxy_agent.name
    if messages[-1].source == user_proxy_agent.name:
        # If the user does not approve, return to the planning agent.
        if "APPROVE" not in messages[-1].content.upper():  # type: ignore
            return planning_agent.name
    return None


# Reset the previous agents and run the chat again with the user proxy agent and selector function.
await team.reset()
team = SelectorGroupChat(
    [planning_agent, web_search_agent, data_analyst_agent, user_proxy_agent],
    model_client=model_client,
    termination_condition=termination,
    selector_prompt=selector_prompt,
    selector_func=selector_func_with_user_proxy,
    allow_repeated_speaker=True,
)

await Console(team.run_stream(task=task))
# Out:
# ---------- user ----------
# Who was the Miami Heat player with the highest points in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?
# ---------- PlanningAgent ----------
# To address the user's query, we will need to perform the following tasks:
#
# 1. Identify the Miami Heat player with the highest points in the 2006-2007 season.
# 2. Find the total rebounds for that player in the 2007-2008 season.
# 3. Find the total rebounds for that player in the 2008-2009 season.
# 4. Calculate the percentage change in the total rebounds between the 2007-2008 and 2008-2009 seasons.
#
# Let's assign these tasks:
#
# 1. **WebSearchAgent**: Identify the Miami Heat player with the highest points in the 2006-2007 season.
#
# (Task 2 and 3 depend on the result of Task 1. We'll proceed with Tasks 2 and 3 once Task 1 is complete.)
# ---------- UserProxyAgent ----------
# approve
# ---------- WebSearchAgent ----------
# [FunctionCall(id='call_0prr3fUnG5CtisUG7QeygW0w', arguments='{"query":"Miami Heat highest points scorer 2006-2007 NBA season"}', name='search_web_tool')]
# ---------- WebSearchAgent ----------
# [FunctionExecutionResult(content='Here are the total points scored by Miami Heat players in the 2006-2007 season:\n        Udonis Haslem: 844 points\n        Dwayne Wade: 1397 points\n        James Posey: 550 points\n        ...\n        ', call_id='call_0prr3fUnG5CtisUG7QeygW0w')]
# ---------- WebSearchAgent ----------
# Here are the total points scored by Miami Heat players in the 2006-2007 season:
#         Udonis Haslem: 844 points
#         Dwayne Wade: 1397 points
#         James Posey: 550 points
#         ...
#
# ---------- PlanningAgent ----------
# Dwyane Wade was the Miami Heat player with the highest points in the 2006-2007 season, scoring 1397 points.
#
# Next, we need to find Dwyane Wade's total rebounds for the 2007-2008 and 2008-2009 seasons:
#
# 2. **WebSearchAgent**: Find Dwyane Wade's total rebounds for the 2007-2008 season.
# 3. **WebSearchAgent**: Find Dwyane Wade's total rebounds for the 2008-2009 season.
# ---------- UserProxyAgent ----------
# approve
# ---------- WebSearchAgent ----------
# [FunctionCall(id='call_fBZe80NaBfruOVGwRWbhXyRm', arguments='{"query": "Dwyane Wade total rebounds 2007-2008 NBA season"}', name='search_web_tool'), FunctionCall(id='call_cURYibna4fGxySiL7IYt0c3s', arguments='{"query": "Dwyane Wade total rebounds 2008-2009 NBA season"}', name='search_web_tool')]
# ---------- WebSearchAgent ----------
# [FunctionExecutionResult(content='The number of total rebounds for Dwayne Wade in the Miami Heat season 2007-2008 is 214.', call_id='call_fBZe80NaBfruOVGwRWbhXyRm'), FunctionExecutionResult(content='The number of total rebounds for Dwayne Wade in the Miami Heat season 2008-2009 is 398.', call_id='call_cURYibna4fGxySiL7IYt0c3s')]
# ---------- WebSearchAgent ----------
# The number of total rebounds for Dwayne Wade in the Miami Heat season 2007-2008 is 214.
# The number of total rebounds for Dwayne Wade in the Miami Heat season 2008-2009 is 398.
# ---------- PlanningAgent ----------
# Now that we have Dwyane Wade's total rebounds for both seasons, we can calculate the percentage change:
#
# 4. **DataAnalystAgent**: Calculate the percentage change in Dwyane Wade's total rebounds from the 2007-2008 season (214 rebounds) to the 2008-2009 season (398 rebounds).
# ---------- UserProxyAgent ----------
# approve
# ---------- DataAnalystAgent ----------
# [FunctionCall(id='call_z3uog7t2x0z1Suzl5hACF9hY', arguments='{"start":214,"end":398}', name='percentage_change_tool')]
# ---------- DataAnalystAgent ----------
# [FunctionExecutionResult(content='85.98130841121495', call_id='call_z3uog7t2x0z1Suzl5hACF9hY')]
# ---------- DataAnalystAgent ----------
# 85.98130841121495
# ---------- PlanningAgent ----------
# Dwyane Wade was the Miami Heat player with the highest points in the 2006-2007 season, scoring 1397 points. His total rebounds increased from 214 in the 2007-2008 season to 398 in the 2008-2009 season, which is a percentage change of approximately 85.98%.
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, content='Who was the Miami Heat player with the highest points in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?', type='TextMessage'), TextMessage(source='PlanningAgent', models_usage=RequestUsage(prompt_tokens=161, completion_tokens=166), content="To address the user's query, we will need to perform the following tasks:\n\n1. Identify the Miami Heat player with the highest points in the 2006-2007 season.\n2. Find the total rebounds for that player in the 2007-2008 season.\n3. Find the total rebounds for that player in the 2008-2009 season.\n4. Calculate the percentage change in the total rebounds between the 2007-2008 and 2008-2009 seasons.\n\nLet's assign these tasks:\n\n1. **WebSearchAgent**: Identify the Miami Heat player with the highest points in the 2006-2007 season.\n   \n(Task 2 and 3 depend on the result of Task 1. We'll proceed with Tasks 2 and 3 once Task 1 is complete.)", type='TextMessage'), UserInputRequestedEvent(source='UserProxyAgent', models_usage=None, request_id='2a433f88-f886-4b39-a078-ea1acdcb2f9d', content='', type='UserInputRequestedEvent'), TextMessage(source='UserProxyAgent', models_usage=None, content='approve', type='TextMessage'), ToolCallRequestEvent(source='WebSearchAgent', models_usage=RequestUsage(prompt_tokens=323, completion_tokens=28), content=[FunctionCall(id='call_0prr3fUnG5CtisUG7QeygW0w', arguments='{"query":"Miami Heat highest points scorer 2006-2007 NBA season"}', name='search_web_tool')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='WebSearchAgent', models_usage=None, content=[FunctionExecutionResult(content='Here are the total points scored by Miami Heat players in the 2006-2007 season:\n        Udonis Haslem: 844 points\n        Dwayne Wade: 1397 points\n        James Posey: 550 points\n        ...\n        ', call_id='call_0prr3fUnG5CtisUG7QeygW0w')], type='ToolCallExecutionEvent'), ToolCallSummaryMessage(source='WebSearchAgent', models_usage=None, content='Here are the total points scored by Miami Heat players in the 2006-2007 season:\n        Udonis Haslem: 844 points\n        Dwayne Wade: 1397 points\n        James Posey: 550 points\n        ...\n        ', type='ToolCallSummaryMessage'), TextMessage(source='PlanningAgent', models_usage=RequestUsage(prompt_tokens=403, completion_tokens=112), content="Dwyane Wade was the Miami Heat player with the highest points in the 2006-2007 season, scoring 1397 points.\n\nNext, we need to find Dwyane Wade's total rebounds for the 2007-2008 and 2008-2009 seasons:\n\n2. **WebSearchAgent**: Find Dwyane Wade's total rebounds for the 2007-2008 season.\n3. **WebSearchAgent**: Find Dwyane Wade's total rebounds for the 2008-2009 season.", type='TextMessage'), UserInputRequestedEvent(source='UserProxyAgent', models_usage=None, request_id='23dd4570-2391-41e9-aeea-86598499792c', content='', type='UserInputRequestedEvent'), TextMessage(source='UserProxyAgent', models_usage=None, content='approve', type='TextMessage'), ToolCallRequestEvent(source='WebSearchAgent', models_usage=RequestUsage(prompt_tokens=543, completion_tokens=73), content=[FunctionCall(id='call_fBZe80NaBfruOVGwRWbhXyRm', arguments='{"query": "Dwyane Wade total rebounds 2007-2008 NBA season"}', name='search_web_tool'), FunctionCall(id='call_cURYibna4fGxySiL7IYt0c3s', arguments='{"query": "Dwyane Wade total rebounds 2008-2009 NBA season"}', name='search_web_tool')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='WebSearchAgent', models_usage=None, content=[FunctionExecutionResult(content='The number of total rebounds for Dwayne Wade in the Miami Heat season 2007-2008 is 214.', call_id='call_fBZe80NaBfruOVGwRWbhXyRm'), FunctionExecutionResult(content='The number of total rebounds for Dwayne Wade in the Miami Heat season 2008-2009 is 398.', call_id='call_cURYibna4fGxySiL7IYt0c3s')], type='ToolCallExecutionEvent'), Tool ...

# %% [markdown]
# Now, the user's feedback is incorporated into the conversation flow,
# and the user can approve or reject the planning agent's decisions.

# %% [markdown]
# ```{tip}
# For more guidance on how to prompt reasoning models, see the
# Azure AI Services Blog on [Prompt Engineering for OpenAI's O1 and O3-mini Reasoning Models](https://techcommunity.microsoft.com/blog/azure-ai-services-blog/prompt-engineering-for-openai%E2%80%99s-o1-and-o3-mini-reasoning-models/4374010)
# ```
